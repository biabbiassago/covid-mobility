# %% [markdown]
# ### Plots for hand-picked ZIP codes in OC.
# March 2020 to Jan 2021

# %%
from IPython.display import Image
print("IRVINE UCI Campus")
Image("outputs/out_plots/92617.png")
# Out:
# IRVINE UCI Campus

# %%
from IPython.display import Image
print("NEWPORT BEACH")
Image("outputs/out_plots/92660.png")
# Out:
# NEWPORT BEACH

# %%
from IPython.display import Image
print("LAGUNA BEACH ")
Image("outputs/out_plots/92651.png")
# Out:
# LAGUNA BEACH

# %%
from IPython.display import Image
print("GARDEN GROVE")
Image("outputs/out_plots/92840.png")
# Out:
# GARDEN GROVE

# %%
from IPython.display import Image
print("SANTA ANA 1")
Image("outputs/out_plots/92701.png")
# Out:
# SANTA ANA 1

# %%
from IPython.display import Image
print("SANTA ANA 2")
Image("outputs/out_plots/92703.png")
# Out:
# SANTA ANA 2

# %%
from IPython.display import Image
print("TUSTIN")
Image("outputs/out_plots/92708.png")
# Out:
# TUSTIN
